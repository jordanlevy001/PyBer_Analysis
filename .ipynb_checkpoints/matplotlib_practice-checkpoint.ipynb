# %%
# Import dependencies.

import matplotlib
matplotlib.__version__


import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
# Set the x- axis to a list of strings for each month
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars acumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create the plot with the MATLAB method
plt.plot(x_axis, y_axis)

# %%
# Create the plot with the object-oriented method: ax.plt().
# Add a legend for the city of Boston
# Change the line width to 2 points
fig, ax = plt.subplots()
ax.plot(x_axis, y_axis, linewidth=2, label='Boston')

ax.legend()

# Change line color to green

# Change the marker to a diamond

# Add a title and axes labels
ax.set_title("PyBer Fare by Month")
ax.set_xlabel('Date')
ax.set_ylabel('Fare($)')

# Add a y-axis limit
ax.set_ylim(0, 45)
# Add grid lines
ax.grid()

# %%
# Create the plot and add a label for the legend
plt.plot(x_axis, y_axis, marker="*", color="blue", linewidth=2, label='Boston')
# Create labels for the x and y axes
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Set the y limit between 0 and 45
plt.ylim(0,45)
# Create a title.
plt.title("PyBer Fare by Month")
# Add a grid.
plt.grid()
# Add the legend.
plt.legend()

# %%
# Bar Charts

# %%
# Create the plot
plt.bar(x_axis, y_axis, color='green', label='Boston')

# Create labels for the x and y axes
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Create a title
plt.title("PyBer Fare by Month")
# Add the legend
plt.legend()

# %%
# Create a horizontal bar chart
plt.barh(x_axis, y_axis, color="magenta", label='Boston')

# Create the plot
plt.gca().invert_yaxis()

plt.xlabel("Date")
plt.ylabel("Fare($)")
plt.title("PyBer Fare by Month")
plt.legend()

# %%
# Create a vertical bar chart with ax.plt()
fig, ax = plt.subplots()
ax.bar(x_axis, y_axis, color="black", label='New York')
# Out:
# <BarContainer object of 12 artists>

# %%
# Create a horizontal bar chart using the object-oriented interface method
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis, color="cyan", label='Chicago')
ax.invert_yaxis()

ax.set_xlabel('Fare($)')
ax.set_ylabel('Date')
ax.set_title("PyBer Fare by Month")
ax.legend()

# %%
# Scatter Plots

# %%
plt.plot(x_axis, y_axis, 'o')

# %%
plt.scatter(y_axis, x_axis, c="red", label='Chicago')
plt.legend()
plt.ylabel("Date")
plt.xlabel("Fare($)")
plt.title("PyBer Fare by Month")

plt.gca().invert_yaxis()

plt.xlim(0, 50)
# Out:
# (0.0, 50.0)

# %%
# Bubble Charts

# %%
y_axis_larger = []
for data in y_axis:
    y_axis_larger.append(data*3)

# %%
# Use list comprehension to increase the size of the markers

plt.scatter(x_axis, y_axis, s= [i * 3 for i in y_axis])

# %%
# Create a scatter plot using the object-oriented interface method
fig, ax = plt.subplots()
ax.scatter(x_axis, y_axis)

# %%
# Create a bubble chart using the object-oriented interface method
fig, ax = plt.subplots()
ax.scatter(y_axis, x_axis, s = [i * 5 for i in y_axis], color='skyblue', alpha=0.8, edgecolor='black', label='Boston')

ax.set_xlabel('Fare($)')
ax.set_ylabel('Date')
ax.set_title("PyBer Fare by Month")

ax.set_xlim(0, 50)

ax.invert_yaxis()
ax.legend()

# %%
# Creating Pie Charts

# %%
# Create a pie chart using the MATLAB method:

# %%
# Assign 12 colors, one for each month
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]
explode_values = (0, 0, 0.2, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)

plt.subplots(figsize=(8,8))
plt.pie(y_axis, 
        explode=explode_values, labels=x_axis,
        colors=colors,
        autopct='%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7fec7b4cbfd0>,
#   <matplotlib.patches.Wedge at 0x7fec88241700>,
#   <matplotlib.patches.Wedge at 0x7fec88241d90>,
#   <matplotlib.patches.Wedge at 0x7fec8824e460>,
#   <matplotlib.patches.Wedge at 0x7fec8824eaf0>,
#   <matplotlib.patches.Wedge at 0x7fec8825b1c0>,
#   <matplotlib.patches.Wedge at 0x7fec8825b790>,
#   <matplotlib.patches.Wedge at 0x7fec8825bd90>,
#   <matplotlib.patches.Wedge at 0x7fec8826a370>,
#   <matplotlib.patches.Wedge at 0x7fec8826aa00>,
#   <matplotlib.patches.Wedge at 0x7fec882780a0>,
#   <matplotlib.patches.Wedge at 0x7fec88278730>],
#  [Text(1.0940372721655667, 0.11437852557419124, 'Jan'),
#   Text(0.9905193092273052, 0.4784051609753622, 'Feb'),
#   Text(0.5907474957304654, 1.1580230551626267, 'Mar'),
#   Text(-0.32930826971286276, 1.0495504101750999, 'April'),
#   Text(-0.9306200792045569, 0.5864693241605263, 'May'),
#   Text(-1.0983369533258995, -0.06046434452452757, 'June'),
#   Text(-0.913463027456946, -0.9249785389235748, 'July'),
#   Text(-0.23338752507546193, -1.0749559354406817, 'Aug'),
#   Text(0.021097559209412746, -1.099797660024518, 'Sept'),
#   Text(0.460981299980763, -0.9987473359504124, 'Oct'),
#   Text(0.8868706338501641, -0.6507384104340302, 'Nov'),
#   Text(1.0760953148482877, -0.22807646384834376, 'Dec')],
#  [Text(0.5967476029993999, 0.06238828667683158, '3.3%'),
#   Text(0.5402832595785301, 0.2609482696229248, '7.7%'),
#   Text(0.36353692044951713, 0.7126295724077703, '13.0%'),
#   Text(-0.17962269257065241, 0.5724820419136908, '11.7%'),
#   Text(-0.5076109522933946, 0.3198923586330143, '10.7%'),
#   Text(-0.5990928836323088, -0.03298055155883321, '8.9%'),
#   Text(-0.562131093819659, -0.5692175624145076, '14.5%'),
#   Text(-0.1273022864047974, -0.5863396011494626, '3.5%'),
#   Text(0.011507759568770587, -0.5998896327406462, '3.9%'),
#   Text(0.2514443454440525, -0.5447712741547703, '9.2%'),
#   Text(0.4837476184637258, -0.35494822387310737, '6.9%'),
#   Text(0.5869610808263387, -0.12440534391727841, '6.6%')])

# %%
# Create the same pie chart as above using object-oriented interface
# method

# %%
fig, ax = plt.subplots()
ax.pie(y_axis,
      labels=x_axis,
      explode = explode_values,
       autopct='%.1f%%',
       colors=colors,
      shadow=True, radius=2)
# Out:
# ([<matplotlib.patches.Wedge at 0x7feca8231d00>,
#   <matplotlib.patches.Wedge at 0x7fec7b4bf940>,
#   <matplotlib.patches.Wedge at 0x7fec7b4a0280>,
#   <matplotlib.patches.Wedge at 0x7fec7b4b1070>,
#   <matplotlib.patches.Wedge at 0x7fec7b4a8c40>,
#   <matplotlib.patches.Wedge at 0x7fec98ea0160>,
#   <matplotlib.patches.Wedge at 0x7fec98ea0640>,
#   <matplotlib.patches.Wedge at 0x7fec7b717400>,
#   <matplotlib.patches.Wedge at 0x7fec7b717c10>,
#   <matplotlib.patches.Wedge at 0x7fec98dc0f40>,
#   <matplotlib.patches.Wedge at 0x7fec98dc01c0>,
#   <matplotlib.patches.Wedge at 0x7fec98daef70>],
#  [Text(2.1880745443311334, 0.2287570511483825, 'Jan'),
#   Text(1.9810386184546105, 0.9568103219507244, 'Feb'),
#   Text(1.0906107613485514, 2.1378887172233108, 'Mar'),
#   Text(-0.6586165394257255, 2.0991008203501997, 'April'),
#   Text(-1.8612401584091138, 1.1729386483210527, 'May'),
#   Text(-2.196673906651799, -0.12092868904905514, 'June'),
#   Text(-1.686393281458977, -1.707652687243523, 'July'),
#   Text(-0.46677505015092385, -2.1499118708813634, 'Aug'),
#   Text(0.04219511841882549, -2.199595320049036, 'Sept'),
#   Text(0.921962599961526, -1.9974946719008249, 'Oct'),
#   Text(1.7737412677003281, -1.3014768208680605, 'Nov'),
#   Text(2.1521906296965754, -0.4561529276966875, 'Dec')],
#  [Text(1.1934952059987998, 0.12477657335366316, '3.3%'),
#   Text(1.0805665191570601, 0.5218965392458496, '7.7%'),
#   Text(0.6361896107866549, 1.2471017517135978, '13.0%'),
#   Text(-0.35924538514130483, 1.1449640838273816, '11.7%'),
#   Text(-1.0152219045867892, 0.6397847172660286, '10.7%'),
#   Text(-1.1981857672646177, -0.06596110311766643, '8.9%'),
#   Text(-0.9837294141844033, -0.9961307342253882, '14.5%'),
#   Text(-0.2546045728095948, -1.1726792022989252, '3.5%'),
#   Text(0.023015519137541175, -1.1997792654812924, '3.9%'),
#   Text(0.502888690888105, -1.0895425483095407, '9.2%'),
#   Text(0.9674952369274517, -0.7098964477462147, '6.9%'),
#   Text(1.1739221616526774, -0.24881068783455682, '6.6%')])
